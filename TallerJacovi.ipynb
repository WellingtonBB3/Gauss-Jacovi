# %% [markdown]
# # Nombre: Wellington Barros
# # [Taller 05] métodos iterativos

# %% [markdown]
# **Resolver Sistema
# Usando funciones provistas
# Gauss Jacobi, Gauss Seidel
# Graficar trayectoria divergencia
# Obtener trayectoria de puntos
# Desde x0 hasta sol
# Graficar trayectoria convergencia
# Intercambiar filas**

# %% [markdown]
# **Link del repositorio:** https://github.com/WellingtonBB3/Gauss-Jacovi

# %%
# %load_ext autoreload
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# **Ejercicios con Divergencia**

# %%
# %autoreload 2
from src.iterative_methods import gauss_jacobi

A = [[2,10],[3,2]]

b = [16, 11]
x0 = [1,1]
tol = 1e-6
max_iter = 100

x,tray_jacobi = gauss_jacobi(A=A, b=b, x0=x0, tol=tol, max_iter=max_iter)
# Out:
# [01-25 20:42:38][INFO] i= 0 x: [[1. 1.]]
# [01-25 20:42:38][INFO] i= 1 x: [[3. 4.]]
# [01-25 20:42:38][INFO] i= 2 x: [[-12.   1.]]
# [01-25 20:42:38][INFO] i= 3 x: [[ 3.  23.5]]
# [01-25 20:42:38][INFO] i= 4 x: [[-109.5    1. ]]
# [01-25 20:42:38][INFO] i= 5 x: [[  3.   169.75]]
# [01-25 20:42:38][INFO] i= 6 x: [[-840.75    1.  ]]
# [01-25 20:42:38][INFO] i= 7 x: [[   3.    1266.625]]
# [01-25 20:42:38][INFO] i= 8 x: [[-6.325125e+03  1.000000e+00]]
# [01-25 20:42:38][INFO] i= 9 x: [[3.0000000e+00 9.4931875e+03]]
# [01-25 20:42:38][INFO] i= 10 x: [[-4.74579375e+04  1.00000000e+00]]
# [01-25 20:42:38][INFO] i= 11 x: [[3.00000000e+00 7.11924062e+04]]
# [01-25 20:42:38][INFO] i= 12 x: [[-3.55954031e+05  1.00000000e+00]]
# [01-25 20:42:38][INFO] i= 13 x: [[3.00000000e+00 5.33936547e+05]]
# [01-25 20:42:38][INFO] i= 14 x: [[-2.66967473e+06  1.00000000e+00]]
# [01-25 20:42:38][INFO] i= 15 x: [[3.0000000e+00 4.0045176e+06]]
# [01-25 20:42:38][INFO] i= 16 x: [[-2.002258e+07  1.000000e+00]]
# ...

# %%
import numpy as np  
import matplotlib.pyplot as plt

trayectoria_jacobi = np.squeeze(np.array(tray_jacobi))
valores_x1 = trayectoria_jacobi[:, 0] 
valores_x2 = trayectoria_jacobi[:, 1] 

# Graficar la relación entre x1 y x2
plt.plot(
    valores_x1, 
    valores_x2, 
    marker='o', 
    label="Trayectoria $(x_1, x_2)$", 
    linestyle='-', 
    color='green'  # 
)

# Personalizar la gráfica
plt.title("Gauss-Jacobi: Trayectoria de la solución")
plt.xlabel("$x_1$")
plt.ylabel("$x_2$")
plt.grid()
plt.legend()  
plt.show()

# %%
from src.iterative_methods import gauss_seidel

matriz_A = [[2, 10], [3, 2]]
vector_b = [16, 11]
vector_inicial = [1, 1]
tolerancia = 1e-6
maximo_iteraciones = 100

solucion_seidel, trayectoria_seidel = gauss_seidel(
    A=matriz_A, b=vector_b, x0=vector_inicial, tol=tolerancia, max_iter=maximo_iteraciones
)
# Out:
# [01-25 20:47:05][INFO] i= 0 x: [[1. 1.]]
# [01-25 20:47:05][INFO] i= 1 x: [[3. 1.]]

# %%
import numpy as np  
import matplotlib.pyplot as plt

trayectoria_seidel = np.squeeze(np.array(trayectoria_seidel))
valores_x1_seidel = trayectoria_seidel[:, 0]
valores_x2_seidel = trayectoria_seidel[:, 1]

plt.plot(
    valores_x1_seidel, 
    valores_x2_seidel, 
    marker='o', 
    label="Trayectoria $(x_1, x_2)$", 
    linestyle='-', 
    color='blue'
)

plt.scatter(
    valores_x1_seidel[0], 
    valores_x2_seidel[0], 
    color='orange', 
    label="Punto inicial", 
    zorder=5
)

plt.scatter(
    valores_x1_seidel[-1], 
    valores_x2_seidel[-1], 
    color='purple', 
    label="Solución final", 
    zorder=5
)

plt.title("Gauss-Seidel: Trayectoria de la solución", color='darkblue')
plt.xlabel("$x_1$", color='darkgreen')
plt.ylabel("$x_2$", color='darkgreen')
plt.grid()
plt.legend()  
plt.show()

# %% [markdown]
# **Ejercicios con Convergencia**

# %%
import numpy as np  
import matplotlib.pyplot as plt

matriz_A = np.array([[3, 2], [2, 10]], dtype=float)
vector_b = np.array([11, 16], dtype=float)
vector_inicial = np.array([[1], [1]])
tolerancia = 1e-5
maximo_iteraciones = 100

solucion_jacobi, trayectoria_jacobi = gauss_jacobi(
    A=matriz_A, b=vector_b, x0=vector_inicial, tol=tolerancia, max_iter=maximo_iteraciones
)
trayectoria_jacobi = np.squeeze(np.array(trayectoria_jacobi))
valores_x1_jacobi = trayectoria_jacobi[:, 0]
valores_x2_jacobi = trayectoria_jacobi[:, 1]

solucion_seidel, trayectoria_seidel = gauss_seidel(
    A=matriz_A, b=vector_b, x0=vector_inicial, tol=tolerancia, max_iter=maximo_iteraciones
)
trayectoria_seidel = np.squeeze(np.array(trayectoria_seidel))
valores_x1_seidel = trayectoria_seidel[:, 0]
valores_x2_seidel = trayectoria_seidel[:, 1]

plt.plot(
    valores_x1_jacobi, 
    valores_x2_jacobi, 
    marker='o', 
    color='blue', 
    label="Trayectoria Gauss-Jacobi", 
    linestyle='-'
)
plt.plot(
    valores_x1_seidel, 
    valores_x2_seidel, 
    marker='^', 
    color='red', 
    label="Trayectoria Gauss-Seidel", 
    linestyle='-.'
)

plt.title("Gauss-Jacobi vs Gauss-Seidel", color='purple')
plt.xlabel("$x_1$", color='darkgreen')
plt.ylabel("$x_2$", color='darkgreen')
plt.grid()
plt.legend()
plt.show()
# Out:
# [01-25 20:51:20][INFO] i= 0 x: [[1 1]]
# [01-25 20:51:20][INFO] i= 1 x: [[3.  1.4]]
# [01-25 20:51:20][INFO] i= 2 x: [[2.73333333 1.        ]]
# [01-25 20:51:20][INFO] i= 3 x: [[3.         1.05333333]]
# [01-25 20:51:20][INFO] i= 4 x: [[2.96444444 1.        ]]
# [01-25 20:51:20][INFO] i= 5 x: [[3.         1.00711111]]
# [01-25 20:51:20][INFO] i= 6 x: [[2.99525926 1.        ]]
# [01-25 20:51:20][INFO] i= 7 x: [[3.         1.00094815]]
# [01-25 20:51:20][INFO] i= 8 x: [[2.9993679 1.       ]]
# [01-25 20:51:20][INFO] i= 9 x: [[3.         1.00012642]]
# [01-25 20:51:20][INFO] i= 10 x: [[2.99991572 1.        ]]
# [01-25 20:51:20][INFO] i= 11 x: [[3.         1.00001686]]
# [01-25 20:51:20][INFO] i= 12 x: [[2.99998876 1.        ]]
# [01-25 20:51:20][INFO] i= 13 x: [[3.         1.00000225]]
# [01-25 20:51:20][INFO] i= 0 x: [[1 1]]
# [01-25 20:51:20][INFO] i= 1 x: [[3. 1.]]

# %%
import numpy as np  
import matplotlib.pyplot as plt

matriz_A = np.array([[3, 2], [2, 10]], dtype=float)
vector_b = np.array([11, 16], dtype=float)
vector_inicial = np.array([[5], [-2]])
tolerancia = 1e-5
maximo_iteraciones = 100

solucion_jacobi, trayectoria_jacobi = gauss_jacobi(
    A=matriz_A, b=vector_b, x0=vector_inicial, tol=tolerancia, max_iter=maximo_iteraciones
)
trayectoria_jacobi = np.squeeze(np.array(trayectoria_jacobi))
valores_x1_jacobi = trayectoria_jacobi[:, 0]
valores_x2_jacobi = trayectoria_jacobi[:, 1]

solucion_seidel, trayectoria_seidel = gauss_seidel(
    A=matriz_A, b=vector_b, x0=vector_inicial, tol=tolerancia, max_iter=maximo_iteraciones
)
trayectoria_seidel = np.squeeze(np.array(trayectoria_seidel))
valores_x1_seidel = trayectoria_seidel[:, 0]
valores_x2_seidel = trayectoria_seidel[:, 1]

plt.plot(
    valores_x1_jacobi, 
    valores_x2_jacobi, 
    marker='o', 
    color='cyan', 
    label="Trayectoria Gauss-Jacobi", 
    linestyle='-'
)
plt.plot(
    valores_x1_seidel, 
    valores_x2_seidel, 
    marker='^', 
    color='orange', 
    label="Trayectoria Gauss-Seidel", 
    linestyle='-.'
)

plt.title("Gauss-Jacobi vs Gauss-Seidel", color='blue')
plt.xlabel("$x_1$", color='darkred')
plt.ylabel("$x_2$", color='darkred')
plt.grid()
plt.legend()
plt.show()
# Out:
# [01-25 20:52:10][INFO] i= 0 x: [[ 5 -2]]
# [01-25 20:52:10][INFO] i= 1 x: [[5.  0.6]]
# [01-25 20:52:10][INFO] i= 2 x: [[3.26666667 0.6       ]]
# [01-25 20:52:10][INFO] i= 3 x: [[3.26666667 0.94666667]]
# [01-25 20:52:10][INFO] i= 4 x: [[3.03555556 0.94666667]]
# [01-25 20:52:10][INFO] i= 5 x: [[3.03555556 0.99288889]]
# [01-25 20:52:10][INFO] i= 6 x: [[3.00474074 0.99288889]]
# [01-25 20:52:10][INFO] i= 7 x: [[3.00474074 0.99905185]]
# [01-25 20:52:10][INFO] i= 8 x: [[3.0006321  0.99905185]]
# [01-25 20:52:10][INFO] i= 9 x: [[3.0006321  0.99987358]]
# [01-25 20:52:10][INFO] i= 10 x: [[3.00008428 0.99987358]]
# [01-25 20:52:10][INFO] i= 11 x: [[3.00008428 0.99998314]]
# [01-25 20:52:10][INFO] i= 12 x: [[3.00001124 0.99998314]]
# [01-25 20:52:10][INFO] i= 13 x: [[3.00001124 0.99999775]]
# [01-25 20:52:10][INFO] i= 0 x: [[ 5 -2]]
# [01-25 20:52:10][INFO] i= 1 x: [[5.  0.6]]
# [01-25 20:52:10][INFO] i= 2 x: [[3.26666667 0.94666667]]
# ...
